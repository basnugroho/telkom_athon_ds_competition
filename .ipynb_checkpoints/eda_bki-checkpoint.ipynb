# %%
import pandas as pd
import numpy as np
import mysql.connector
from mysql.connector import Error
from datetime import datetime
import env
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def run_query(sql_name):
    # Connect to the MySQL database (replace the placeholders with your actual credentials)
    host = '10.48.103.23'
    user = 't_2023_user'        
    password = '99tpZBfpXn'
    database = 'master'
    port = 33144

    # Create a connection to the database
    connection = mysql.connector.connect(host=host, user=user, password=password, database=database, port=port)

    # Create a cursor object to execute the SQL query
    cursor = connection.cursor()

    # Define the SQL query
    current_dir = f"./"
    file_path = f'{current_dir}{sql_name}'

    # Read the content of the file into a variable
    with open(file_path, 'r') as file:
        query = file.read()

    # Execute the query
    cursor.execute(query)

    # Fetch all the results into a list of tuples
    results = cursor.fetchall()

    # Get the column names from the cursor description
    columns = [col[0] for col in cursor.description]

    # Close the cursor and the connection
    cursor.close()
    connection.close()

    # Create a DataFrame from the results and column names
    df = pd.DataFrame(results, columns=columns)
    return df

# mager maka auto hapus yg korelasi tinggi
def remove_highly_correlated_features(df, threshold=0.9):
    """
    Menghapus fitur yang memiliki korelasi lebih dari ambang batas tertentu.
    
    Parameters:
    - df: DataFrame yang berisi fitur-fitur yang akan diperiksa.
    - threshold: Ambang batas korelasi.
    
    Returns:
    - DataFrame yang telah dikurangi fiturnya.
    """
    # Hanya mengambil kolom numerik untuk korelasi
    numeric_df = df.select_dtypes(include=[np.number])
    correlation_matrix = numeric_df.corr().abs()
    
    # Dapatkan matriks segitiga atas dari matriks korelasi
    upper_triangle = correlation_matrix.where(
        np.triu(np.ones(correlation_matrix.shape), k=1).astype(bool))
    
    #print(f"kolom dengan korelasi di atas {threshold}: {upper_triangle.columns}")
    
    # Temukan indeks kolom fitur yang memiliki korelasi lebih dari ambang batas
    to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]
    
    return df.drop(columns=to_drop)

def manual_oversample(X, y):
    # Dapatkan indeks dari kelas minoritas
    minority_class_indices = y[y == 1].index
    majority_class_indices = y[y == 0].index
    
    # Hitung jumlah kelas mayoritas
    num_majority = len(y[y == 0])
    
    # Dapatkan sampel acak dari kelas minoritas
    random_minority_indices = np.random.choice(minority_class_indices, num_majority, replace=True)
    
    # Gabungkan indeks kelas mayoritas dengan sampel acak dari kelas minoritas
    over_sample_indices = np.concatenate([majority_class_indices, random_minority_indices])
    
    # Dapatkan data yang oversampled
    X_oversampled = X.loc[over_sample_indices]
    y_oversampled = y.loc[over_sample_indices]
    
    return X_oversampled, y_oversampled

# %%
#download dataset
download_df = run_query("eda/DATASET_BKI.sql")
print("downloading...")
# download_df.set_index('reco_id_curr')
download_df.to_csv("eda/DATASET_BKI.csv")
print("csv generated")
# Out:
# downloading...
# csv generated

# %%
plt.style.use('ggplot')
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('eda/DATASET_BKI.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.describe()
# Out:
#          days_credit  credit_day_overdue  days_credit_enddate  \
# count  338866.000000        338866.00000        338866.000000
# mean    -1140.075304             0.95034           437.351773
# std       799.381575            40.17249          4843.039939
# min     -2922.000000             0.00000        -42060.000000
# 25%     -1663.000000             0.00000         -1089.000000
# 50%      -985.000000             0.00000          -268.000000
# 75%      -469.000000             0.00000           330.000000
# max         0.000000          2792.00000         31198.000000
#
#        days_enddate_fact  credit_limit_max_overdue  credit_prolong_count  \
# count      338866.000000              3.388660e+05         338866.000000
# mean         -643.608943              1.182476e+03              0.007144
# std           750.419832              3.712291e+04              0.101828
# min         -2919.000000              0.000000e+00              0.000000
# 25%         -1084.000000              0.000000e+00              0.000000
# 50%          -357.000000              0.000000e+00              0.000000
# 75%             0.000000              0.000000e+00              0.000000
# max             0.000000              1.314450e+07              6.000000
#
#          credit_sum  credit_sum_debt  credit_sum_limit  credit_sum_overdue  \
# count  3.388660e+05     3.388660e+05      3.388660e+05        3.388660e+05
# mean   3.140744e+05     1.027263e+05      4.060766e+03        3.070675e+01
# std    7.859205e+05     5.535188e+05      3.421420e+04        5.562517e+03
# min    0.000000e+00    -1.354880e+06     -3.163920e+05        0.000000e+00
# 25%    4.912650e+04     0.000000e+00      0.000000e+00        0.000000e+00
# 50%    1.154250e+05     0.000000e+00      0.000000e+00        0.000000e+00
# 75%    2.700000e+05     7.182000e+01      0.000000e+00        0.000000e+00
# max    6.220300e+07     6.457020e+07      2.045370e+06        2.387230e+06
#
#        days_credit_update  annuity_payment
# count       338866.000000     3.388660e+05
# mean          -601.584809     3.477316e+03
# std            728.763391     1.204669e+05
# min         -41946.000000     0.000000e+00
# 25%           -907.000000     0.000000e+00
# 50%           -413.000000     0.000000e+00
# 75%            -34.000000     0.000000e+00
# max            372.000000     5.747620e+07

# %%
df.shape
# Out:
# (338866, 17)

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-7OJPD63:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# C:\Users\basnugroho\anaconda3\envs\py310\lib\site-packages\seaborn\matrix.py:309: UserWarning:
#
# Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#
# C:\Users\basnugroho\anaconda3\envs\py310\lib\site-packages\seaborn\matrix.py:309: UserWarning:
#
# Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#
# 2023-09-30 22:57:07,027 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,032 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,033 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,034 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,034 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,035 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,035 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,036 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,037 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,038 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,039 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,040 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,041 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,042 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,042 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,044 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,045 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,046 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,046 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,057 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,058 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,058 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,059 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,060 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,060 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,061 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,062 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,063 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,063 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,064 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,065 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,066 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,067 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,069 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,070 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,071 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,071 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:07,072 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,106 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,110 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,114 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,115 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,116 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,117 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,118 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,119 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,120 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,120 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,121 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,123 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,123 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,124 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,125 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,126 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,127 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,128 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,129 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,148 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,150 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,151 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,152 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,154 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,155 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,156 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,158 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,159 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,161 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,162 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,164 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,165 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,166 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,168 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,169 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,170 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,173 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,174 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,175 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,176 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,176 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,177 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,178 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,179 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,180 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,181 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,182 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,183 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,206 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,207 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,208 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,209 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,209 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,210 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,211 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,212 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,213 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,214 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,215 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,238 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,239 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,240 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,241 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,242 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,243 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,244 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,245 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,246 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,246 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,247 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,248 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,249 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,250 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,251 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,252 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:11,253 - WARNING  - findfont: Font family 'Heiti TC' not found.
# C:\Users\basnugroho\anaconda3\envs\py310\lib\site-packages\scipy\cluster\hierarchy.py:2847: UserWarning:
#
# Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#
# 2023-09-30 22:57:18,776 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,778 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,779 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,779 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,780 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,781 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,781 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,782 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,783 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,784 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,785 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,786 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,787 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,787 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,788 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,789 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,790 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,791 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,801 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,802 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,803 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,804 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,805 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,806 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,808 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,809 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,810 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,811 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,812 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,813 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,814 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,815 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,816 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,817 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,819 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,826 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,829 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,829 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,830 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,831 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,831 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,832 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,833 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,834 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,835 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:18,835 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,234 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,237 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,238 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,239 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,240 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,241 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,242 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,243 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,243 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,244 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,245 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,246 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,247 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,248 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,249 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,250 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,251 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,252 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,252 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,253 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,254 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,255 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,361 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,362 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,363 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,365 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,366 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,367 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,368 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,369 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,371 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,372 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,373 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,374 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,375 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,376 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,378 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,379 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,380 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,383 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,384 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,384 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,385 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-09-30 22:57:25,386 - WARNING  - findfont: Font family 'Heiti TC' not found.
